# %%
from MontePython import Portfolio as pf

# %%
newport = pf('Shivs Portfolio')

# %%
pf_list = ['SIRI','PYPL','IUSG','PDD','T','TMUS','DIS','ABBV','VZ','SPOT','AXP','FIS','WMT','BABA','AMZN','CSCO','MSFT','JNJ','UNH','ABT','COST','DG','TPAY','SHOP','SAM']

start_date = '2017-5-1'
end_date = '2020-5-12'

newport.addstock(s=pf_list,ds=start_date,de=end_date)
# Out:
# Last 10 Days:
#                 SIRI        PYPL       IUSG        PDD          T       TMUS  \
# Date
# 2020-04-29  5.906403  123.580002  65.437393  48.860001  31.430000  89.309998
# 2020-04-30  5.896426  123.000000  65.138176  47.439999  30.469999  87.800003
# 2020-05-01  5.786679  120.610001  63.532417  45.430000  29.900000  86.199997
# 2020-05-04  5.736794  123.660004  63.941338  46.369999  29.600000  88.959999
# 2020-05-05  5.726816  125.430000  64.579651  48.720001  29.740000  88.970001
# 2020-05-06  5.647000  128.309998  64.609573  49.200001  28.790001  86.589996
# 2020-05-07  5.520000  146.289993  65.517181  50.049999  28.889999  95.290001
# 2020-05-08  5.750000  144.960007  66.404839  54.599998  29.790001  98.519997
# 2020-05-11  5.660000  143.960007  66.843681  54.939999  29.379999  96.720001
# 2020-05-12  5.430000  141.029999  65.417442  57.830002  28.889999  94.610001
#
#                    DIS       ABBV         VZ        SPOT  ...       CSCO  \
# ...

# %%
investment_amt = 100000
min_exposure = 0.01
max_exposure = 0.1

newport.optimal_port(invest=investment_amt,min_ex=min_exposure,max_ex=max_exposure)
# Out:
# SIRI(0.01): $1000.0 @ $5.43 per share(#184)r: 3.82%
# ---
# PYPL(0.025): $2500.0 @ $141.03 per share(#17)r: 35.91%
# ---
# IUSG(0.01): $1000.0 @ $65.42 per share(#15)r: 12.139999999999999%
# ---
# PDD(0.035): $3500.0000000000005 @ $57.83 per share(#60)r: 43.18%
# ---
# T(0.01): $1000.0 @ $28.89 per share(#34)r: -4.2299999999999995%
# ---
# TMUS(0.01): $1000.0 @ $94.61 per share(#10)r: 10.76%
# ---
# DIS(0.01): $1000.0 @ $104.56 per share(#9)r: -1.6400000000000001%
# ---
# ABBV(0.01): $1000.0 @ $90.46 per share(#11)r: 15.190000000000001%
# ---
# VZ(0.021): $2100.0 @ $55.46 per share(#37)r: 10.68%
# ---
# SPOT(0.01): $1000.0 @ $153.94 per share(#6)r: 1.54%
# ---
# AXP(0.01): $1000.0 @ $83.14 per share(#12)r: 3.1%
# ---
# FIS(0.01): $1000.0 @ $127.59 per share(#7)r: 14.91%
# ---
# WMT(0.1): $10000.0 @ $123.78 per share(#80)r: 18.95%
# ---
# BABA(0.01): $1000.0 @ $200.31 per share(#4)r: 17.849999999999998%
# ---
# AMZN(0.1): $10000.0 @ $2356.95 per share(#4)r: 30.070000000000004%
# ---
# ...
